# %% [markdown]
# <a href="https://colab.research.google.com/github/JithinBV/MulltipleDocbot/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install langchain
# !pip -q install bitsandbytes accelerate xformers einops
# !pip -q install datasets loralib sentencepiece
# !pip -q install pypdf

# !pip -q install sentence_transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 20.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 28.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.0/167.0 MB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 29.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 46.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.3/276.3 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 69.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 107.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.9 MB/s eta 0:00:00
#   Building wheel for sentence_transformers (setup.py) ... done

# %%
# !pip install docx2txt
# Out:
# Collecting docx2txt
#   Downloading docx2txt-0.8.tar.gz (2.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: docx2txt
#   Building wheel for docx2txt (setup.py) ... done
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3959 sha256=9427ec9effb0b5ed612dd16e949c95149a771ea8b3c82aacb734f5a60fc10d3f
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
# Successfully built docx2txt
# Installing collected packages: docx2txt
# Successfully installed docx2txt-0.8

# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-0.4.13-py3-none-any.whl (437 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 437.8/437.8 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.10.12)
# Collecting chroma-hnswlib==0.7.3 (from chromadb)
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 60.6 MB/s eta 0:00:00
# Collecting fastapi>=0.95.2 (from chromadb)
#   Downloading fastapi-0.103.1-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 6.9 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3 (from chromadb)
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 4.3 MB/s eta 0:00:00
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.0.2-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.5.0)
# Collecting pulsar-client>=3.1.0 (from chromadb)
#   Downloading pulsar_client-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 106.3 MB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 96.7 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.13.3)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 8.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.66.1)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb) (6.0.1)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 55.2 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.9.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.23.5)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (3.7.1)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi>=0.95.2->chromadb)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 9.0 MB/s eta 0:00:00
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (23.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb) (1.16.0)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: python-dateutil>2.1 in /usr/local/lib/python3.10/dist-packages (from posthog>=2.4.0->chromadb) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pulsar-client>=3.1.0->chromadb) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb) (2.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting h11>=0.8 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.3 MB/s eta 0:00:00
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (428 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.8/428.8 kB 41.9 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (6.0.1)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 88.7 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-0.20.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.4 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb) (1.1.3)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 738.2 kB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=f9cad8d1ce7a9d56b3c88800e75e18442f433787cec777cb8e53342262be705c
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, monotonic, websockets, uvloop, python-dotenv, pulsar-client, overrides, humanfriendly, httptools, h11, chroma-hnswlib, bcrypt, backoff, watchfiles, uvicorn, starlette, posthog, coloredlogs, onnxruntime, fastapi, chromadb
# Successfully installed backoff-2.2.1 bcrypt-4.0.1 chroma-hnswlib-0.7.3 chromadb-0.4.13 coloredlogs-15.0.1 fastapi-0.103.1 h11-0.14.0 httptools-0.6.0 humanfriendly-10.0 monotonic-1.6 onnxruntime-1.16.0 overrides-7.4.0 posthog-3.0.2 pulsar-client-3.3.0 pypika-0.48.9 python-dotenv-1.0.0 starlette-0.27.0 uvicorn-0.23.2 uvloop-0.17.0 watchfiles-0.20.0 websockets-11.0.3

# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.17.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.7.22)

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.document_loaders import TextLoader
from langchain.document_loaders import Docx2txtLoader

# %%
from langchain.text_splitter import CharacterTextSplitter

# %%
from langchain.embeddings import HuggingFaceEmbeddings

# %%
from langchain.vectorstores import Chroma

# %%
from huggingface_hub import notebook_login

# %%
import torch
import transformers

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
from transformers import pipeline

# %%
from langchain import HuggingFacePipeline
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain/__init__.py:24: UserWarning: Importing HuggingFacePipeline from langchain root module is no longer supported.
#   warnings.warn(

# %%
from langchain.chains import ConversationalRetrievalChain
from langchain.memory import ConversationBufferMemory

# %%
import os
import sys
os.environ['HUGGINGFACEHUB_API_TOKEN'] = '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'

# %%
# !mkdir docs

# %%
document=[]
for file in os.listdir("docs"):
  if file.endswith(".pdf"):
    pdf_path="./docs/"+file
    loader=PyPDFLoader(pdf_path)
    document.extend(loader.load())
  elif file.endswith('.docx') or file.endswith('.doc'):
    doc_path="./docs/"+file
    loader=Docx2txtLoader(doc_path)
    document.extend(loader.load())
  elif file.endswith('.txt'):
    text_path="./docs/"+file
    loader=TextLoader(text_path)
    document.extend(loader.load())

# %%
document
# Out:
# [Document(page_content='Jithin BV -1228126  \n \nLarge Language Model  \n20/07/23  \nLLM:  It is a type of machine Learning that can perform a variety of natural language processing tasks, \nincluding generating and classifying text, answering questions in a conversational manner , and translating \ntext from one language to another. It uses large d atasets to understand, summarize, and generate text-\nbased  content.  \n \n1.Different types of LLMs  (Large Language Models)  \nThere are  three  main  types  of large  language  models  (LLMs)  based on the transformer architecture:  \n1.Autoregressive  Language  Models  (e.g.,  GPT (Generative  Pre-Trained) ):  \n• Autoregressive models generate text by predicting the next word in a sequence \ngiven the previous words.  \n• They are trained to maximize the likelihood of each word in the training dataset, \ngiven its context. The most we ll-known example of an autoregressive language \nmodel is Open AI’s GPT (Generative Pre -trained Transformer) series, with GPT -4 \nbeing the latest and most powerful iteration.  \n2.Autoencoding  Language  Models  (e.g.,  BERT  (Bidirectional  Encoder  Representations  from \nTransformers) ): \n• Autoencoding models, on the other hand, learn to generate a fixed -size vector \nrepresentation (also called embeddings) of input text by reconstructing the \noriginal input from a masked or corrupted version of it.  \n• They are trained to predic t missing or masked words in the input text by \nleveraging the surrounding context. BERT (Bidirectional Encoder Representations \nfrom Transformers), developed by Google, is one of the most famous \nautoencoding language models.  \n• It can be fine -tuned for a vari ety of NLP (Natural Language Processing)  tasks, such \nas sentiment analysis, named entity recognition, and question answering.  \n3.Third one is the  combination  of autoencoding  and autoregressive  such as  T5 model (text \nto text transfer transformer) it is fine tuned for a wide range of NLP tasks.  \n \n \n \nLangChain  \nLangChain  is a framework for developing applications powered by language models. We believe that the \nmost powerful and differentiated applications will not only call out to a language model via an api, but \nwill also:  \n1. Be data -aware: connect a language model to other  sources of data.  \n2. Be agentic: Allow a language model to interact with its environment.  ', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 0}),
#  Document(page_content='Jithin BV -1228126  \n \nAs such, the LangChain framework is designed with the objective in mind to enable those types of \napplications.  \nThere are two main value props the LangChain framework pro vides:  \n1. Components:  LangChain provides modular abstractions for the components necessary  to work \nwith language models. LangChain also has collections of implementations for all these \nabstractions. The components are designed to be easy to use, regardless of whether you are using \nthe rest of the LangChain framework or not.  \n2. Use-Case Specific Ch ains:  Chains can be thought of as assembling these components in particular \nways to best accomplish a particular use case. These are intended to be a higher -level interface \nthrough which people can easily get started with a specific use case. These chains are also \ndesigned to be customizable.  \nWhy use LangChain?  \nYou can create advanced use cases around LLMs with LangChain because it lets you chain together multiple \ncomponents from several modules:  \n• Large language models: LangChain is a standard interface through which you can interact with a \nvariety of LLMs.  \n• Prompt templates:  LangChain provides several classes and functions to make constructing and \nworking with prompts easy.  \n• Memory:  LangChain provides memory components to manage and manipulate previous chat \nmessages and incorporate them into chains. This is crucial for chatbots, which need to remember \nprior interactions.  \n• Agents: LangChain provides agents that have access to a suite of tools. Depending on the user’s \ninput, an agent can  decide which tools to call.  \n \nAll of this means that LangChain makes it possible for developers to build remarkably powerful \napplications by combining LLMs with other sources of computation and knowledge.  \n \n \nApplications  \n• LangChain can be used for chatbots, Generative Question -Answering (GQA), summarization, and \nmuch more.  \n• It can be used to build NLP applications using LLMs.  \n• LangChain can be particularly useful in the complex field of data science.  \n• It can be used to build search engines using LLM em beddings and a vector database . \n \n \n ', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 1}),
#  Document(page_content='Jithin BV -1228126  \n \nDeployment of LLM based application on a cloud instance.  \n21/07/23  \n \nBuild a simple application with langchain using large language model : \nBefore deploying the model to the cloud instance,  we must  build an  application using Langchain . \nUpdate regarding task:  \nAttempt  1: I tried to build a model us ing Jupyter Notebook , LangChain  and OpenAI it failed because  of \nunexpected or unknown errors . \nAttempt 2 : Tried Building a model using LangChain,  Google Colab and OpenAI it  failed because of license \nissue which  caused the error for Open AI API key.  \nAttempt 3:  Trying to build a model with open source llm, with the help of Hugging Face and LangChain . \n \n23/07/23  \nHere is the code for 3rd attempt:  \n!pip -q install langchain huggingface_hub transformers \nsentence_transformers accelerate bitsandbytes  \n \nimport os \nos.environ[ \'HUGGINGFACEHUB_API_TOKEN\' ] = \n\'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\'  \n \nfrom langchain import PromptTemplate, HuggingFaceHub, LLMChain  \n \n \ntemplate = """Question: {question}  \n \nAnswer: Let\'s think step by step."""  \n \nprompt = PromptTemplate(template=template, input_variables=[ "question" ]) \nllm_chain = LLMChain ( prompt=prompt,  \n                     llm=HuggingFaceHub(repo_id= "google/flan -t5-xxl", \n                                        model_kwargs = {"temperature" :0.5, \n                                                      "max_length" :64})) \n \nquestion = "What is the capital of England?"  \nprint(llm_chain.run(question))  \n ', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 2}),
#  Document(page_content='Jithin BV -1228126  \n \nOutput: London is the capital of England. London is the largest city in \nEngland. The answer: London.  \n \nAttempt 3 It worked.  \n \n \n \n \n SUB TASK : Research on deployment of LLMs on AWS, Azure or GCP .  \n• Created Azure  account  and tried to use OpenAI from Azure  but could not  access it because it is  \nasking subscription ID from the organization.  \n \n \n \n \n', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 3}),
#  Document(page_content='Jithin BV -1228126  \n \n \nFailed to access OpenAI on Azure.  \n \n• Tried accessing the account with fake  Id but failed to access  and got a mail from Microsoft  \nstating . that “ The Azure Open AI (Artificial Intelligence)  service is a limited access  feature that \nrequires registration . Microsoft limits access based on Mic rosoft’s eligibility and use case \ncriteria”.  \n \n \n \n25/07/23  \n• After failing in Azure Open AI, I am  trying the same thing in AWS . \n• In AWS we have Bedrock  for Generative AI . \n• The Bedrock  AI has access in selected regions only.  \n \n  \n \n \n', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 4}),
#  Document(page_content='Jithin BV -1228126  \n \n• Select ed some random region . \n• We must  request  access  to the Bedrock  by filling in the form.  \n \n \n \n• Filled the form and  waiting  for access  to Bedrock . \n \n \n \n \n26/07/23   \n• I waited  to get access from AWS but did not  get the mail . \n• So, I started to work on GCP. \n• In GCP we have Vertex AI  like Open AI it also has Generative AI.  \n \n', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 5}),
#  Document(page_content='Jithin BV -1228126  \n \n \n \n \n• Like AWS it also acces sed in fewer regions . \n \n \n \n• But we can access by selecting random regions.  \n• The google provides only up to 11 projects.  \n \n• For extra projects it is chargeable.  \n[NOTE: Azure provides free s ubscription for 30 days, GCP for 90 days and AWS for 12 months , \nrespectively.]  \n', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 6}),
#  Document(page_content='Jithin BV -1228126  \n \n27/07/23  \nBuilding Small App using LangChain and Streamlit:  \n• Program for simple question and answer model : \npip install huggingface_hub  \n# get a token: https://huggingface.co/docs/api -inference/quicktour#get -\nyour-api-token \n \nfrom getpass import getpass \n \nHUGGINGFACEHUB_API_TOKEN = getpass ( ) \n \nimport os \nos.environ[ "HUGGINGFACEHUB_API_TOKEN" ] = \n\'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\'  \n!pip install langchain  \n \nfrom langchain import HuggingFaceHub  \nfrom langchain import PromptTemplate, LLMChain  \n \n \nquestion = "Who won the FIFA World Cup in the year 1994? "  \n \ntemplate = """Question: {question}  \n \nAnswer: Let\'s think step by step."""  \n \nprompt = PromptTemplate(template=template, input_variables=[ "question" ]) \n \n \nrepo_id = "google/flan -t5-xxl"  # See \nhttps://huggingface.co/models?pipeline_tag=text -generation&sort=downloads \nfor some other options  \n \n \nllm = HuggingFaceHub(  \n    repo_id=repo_id, model_kwargs={ "temperature" : 0.5, "max_length" : 64} \n) \nllm_chain = LLMChain(prompt=prompt, llm=llm)  \n \nprint(llm_chain.run(question))  \n \n ', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 7}),
#  Document(page_content='Jithin BV -1228126  \n \noutput: The 1994 FIFA World Cup was won by the German national team. \nGermany was the defending champion.  \n \n• Creating an app using Streamlit : \n%%writefile app2.py  \ndef main():  \n  st.title("question and answer app")  \n \n  question=st.text_input("what is your question?")  \n \n  if st.button("Get answer"):  \n    with st.spinner("Generation Answer..."):  \n      response=llm_chain.run(question)  \n    st.success(response)  \n \nif __name__==\'__main__\':  \n  main() \n \n \n• After building an app I used D atabutton flatform to host the app.  \n• And succeeded.  \n \n \n \n• Now trying to deploy an app  on cloud platforms.  \n \n \n', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 8}),
#  Document(page_content='Jithin BV -1228126  \n \n28/07/23  \n \n• Tried deploying  Streamlit  app on Azure and GCP .  \n• Tried to create instance from GCP .  \n \n \n \n \n• First,  I thought it was charging then I got to know it can be used by given credits . \n• As I am new to this,  I faced the issue  in understanding  the console.  \n• After tr ying in GCP I tried to deploy in Azure . \n \n \n \n• Here we have to create a web  app to  deploy.  \n• Here we can only use Linux, and the free sku also can be used in selected regions only.  \n \n', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 9}),
#  Document(page_content='Jithin BV -1228126  \n \n \n \n• With the free credit we can use chargeable plans also.  \n \n \n \n• Using these trying  to deploy the Streamlit app ( Still working on it).  \n \n \n31/07/23  \n• To deploy an app in Azure  we need a GitHub  repository.  \n• GitHub  repository is disabled in basic plan, we must  take one step above plan to access  GitHub  \nrepository in Azure.  \n• Premium plans are available only in selected regions.  \n• Created GitHub  account.  \n• After Creating GitHub  account,  I created repository . \n• The repository contains streamlit app.  \n', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 10}),
#  Document(page_content='Jithin BV -1228126  \n \n \n \n• Tried to deploy the streamlit app in azure with the help of GitHub repository but failed in \ndeployment due to region (Central USA) . \n \n \n \n• I tried  to deploy u sing different region (East Asia) got succeeded in deployment.  \n', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 11}),
#  Document(page_content='Jithin BV -1228126  \n \n \n \n \n \n01//08/23  \n• But there is an error in a build (working on it).  \n• Checking the error whether it is from GitHub  or azure web app.  \n• Tried deploying colab into GitHub repository and trying.  \n \n \n• Got error after deployment.  \n', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 12}),
#  Document(page_content='Jithin BV -1228126  \n \n \n \n• Failed in deployment.  \n \n02/08/23  \n \n• After checking the error,  I found out  that it was an error in buil d. \n \n \n \n• After checking the logs,  I found out that there was an error in the installation  of requirements . \n• After correcting that,  first I tried to deploy on streamlit app and checked.  \n', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 13}),
#  Document(page_content='Jithin BV -1228126  \n \n• It worked.  \n \n \n \n• By this build error got rectified.  \n \n \n• Waiting for the app to deploy.  \n \n \n \n \n \n \n', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 14}),
#  Document(page_content='Jithin BV -1228126  \n \n03/08/23  \n• App got deployed successfully.  \n \n \n \n \n• After deployment to run the app,  we must  give start up command . \n• Go to configuration -->general settings -->startup command.  \n• In the startup command column give your command for ex my command is [python -m streamlit \nrun JithinBV_app.py --server.port 8000 --server.address 0.0.0.0] . \n \n \n \n \n', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 15}),
#  Document(page_content='Jithin BV -1228126  \n \n• After giving command  click on the link given in defau lt domain.  \n \n \n• finalappstreamlit.azurewebsites.net  \n \n \n \n• App running successfully.  \n \n \n \n \n', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 16}),
#  Document(page_content='Jithin BV -1228126  \n \n07/08/23  \nDeployment of LLM in cloud API  \n \n• Got a second task of deploying LLM models in cloud APi.  \n• Exploring all the cloud platforms to deploy the model.  \n• I tried  to explore both Azure and A WS. \n• After exploring  I thought Amazon sagemaker  is the best  fit. \n• So, I tried to deploy the LLM in Amazon sagemaker.  \n• Created a domain in the Amazon sagemaker.  \n \n \n \n• Working on it.  \n \n08/08/23  \n• Trying to deploy falcon 7b (tiuuae/falcon -7b) on AWS sagemaker.   \n• I deployed the llm on cloud A pi using Colab, HuggingFace and AWS sagemaker.  \nSteps to deploy LLM in cloud Api:  \n• I installed the sagemaker into colab network and started deployment.  \n \n!pip install sagemaker python -dotenv --quiet \nimport sagemaker  \nimport boto3  \n', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 17}),
#  Document(page_content='Jithin BV -1228126  \n \nimport os \nfrom dotenv import load_dotenv  \n \nos.environ[ "aws_access_key_id" ]=\'AKIATZA2Q4EW6GBSLLNS\'  \nos.environ[ "aws_secret_access_key" ]=\'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\'  \n \n• To get an access key Id and  secret access key you need to login to AWS console . \n• There we must  go to IAM --> users --> create user . \n• After creating user se lect the created username  and go to the security credentials . \n• In security credentials go to access key --> create access key --> select local code and add some \ndescription  and create . \n \n \nNote:  The secret access key can be viewed only once so please copy the access key.  \nREGION_NAME = "us-east-1" \nos.environ[ "AWS_DEFAULT_REGION" ] = REGION_NAME  \nROLE_NAME =  \'llmsagemaker\'  \n \n \nauth_arguments = {  \n    \'aws_access_key_id\' :os.environ[ "aws_access_key_id" ], \n    \'aws_secret_access_key\' :os.environ[ "aws_secret_access_key" ], \n    \'region_name\' :REGION_NAME  \n} \n• To create role,  go to IAM  --> role --> create role --> select AWS service and sagemaker execution \nand create role.  \niam = boto3.client( \'iam\', **auth_arguments)  \nrole = iam.get_role(RoleName=ROLE_NAME)[ \'Role\'][\'Arn\'] \n \n \nsession = sagemaker.Session(boto3.Session(**auth_arguments))  \n ', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 18}),
#  Document(page_content='Jithin BV -1228126  \n \nfrom sagemaker.huggingface import get_huggingface_llm_image_uri  \n \n \n# image uri  \nllm_image = get_huggingface_llm_image_uri( "huggingface" ) \n \n \nprint(f"image uri: {llm_image} ") \nfrom sagemaker.huggingface import HuggingFaceModel  \n \n \n# Falcon 7b  \nhub = {\'HF_MODEL_ID\' :\'tiiuae/falcon -7b\'} \n \n \n# Hugging Face Model Class  \nhuggingface_model = HuggingFaceModel(  \n   env=hub,  \n   role=role,  # iam role from AWS  \n   image_uri=llm_image,  \n   sagemaker_session=session  \n) \n# Deploy model to SageMaker  \npredictor = huggingface_model.deploy(  \n  initial_instance_count= 1, # number of instances  \n  instance_type= \'ml.g5.2xlarge\'  \n  container_startup_health_check_timeout= 300 \n) \n• To deploy the model, we require a gpu.  \n• So, we must request m1.g5.2xlarge gpu from amazon.  \n• After requesting it takes at least 1 to 2 days to allocate the instance.  ', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 19}),
#  Document(page_content='Jithin BV -1228126  \n \n \n10/08/23  \n• After nearly 2 days I got the gpu requested.  \n \n \n \n• It takes 7 -8 min to deploy.  \n# define prompt  \nprompt = """You are the most advanced AI assistant on the planet, called Falcon.  \n \n \nUser: Who won the 2011 cricket world cup? Think step by step.  \nFalcon:"""  \n \n \n# hyperparameters for llm  \nrequest = {  \n  "inputs" : prompt,  \n  "parameters" : { \n    "do_sample" : True, \n    "top_p": 0.9, \n', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 20}),
#  Document(page_content='Jithin BV -1228126  \n \n    "temperature" : 0.5, \n    "max_new_tokens" : 512, \n    "stop": ["\\nUser:","<|endoftext|>" ,"</s>"] \n  } \n} \n \n \n# request to endpoint  \nresponse = predictor.predict(request)  \n \n \n# model response  \nassistant = response[ 0]["generated_text" ][len(prompt):]  \nprint(assistant)  \nOutput:  "The 2011 cricket world cup was won by India. The final was held in Wankhede stadium, Mumbai. \nThe final match was between India and Sri Lanka. India won the match by 6 wickets. Sachin Tendulkar was the \nman of the match for his 91 not out." User:  \n \n• Got deployed successfully.  \n ', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 21})]

# %%
len(document)
# Out:
# 22

# %%
document_splitter=CharacterTextSplitter(separator='\n', chunk_size=500, chunk_overlap=100)

# %%
document_chunks=document_splitter.split_documents(document)

# %%
 len(document_chunks)
# Out:
# 47

# %%
document_chunks[0]
# Out:
# Document(page_content='Jithin BV -1228126  \n \nLarge Language Model  \n20/07/23  \nLLM:  It is a type of machine Learning that can perform a variety of natural language processing tasks, \nincluding generating and classifying text, answering questions in a conversational manner , and translating \ntext from one language to another. It uses large d atasets to understand, summarize, and generate text-\nbased  content.  \n \n1.Different types of LLMs  (Large Language Models)', metadata={'source': './docs/Jithin_BV (1).pdf', 'page': 0})

# %%
embeddings = HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
embeddings
# Out:
# HuggingFaceEmbeddings(client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False})
#   (2): Normalize()
# ), model_name='sentence-transformers/all-MiniLM-L6-v2', cache_folder=None, model_kwargs={}, encode_kwargs={}, multi_process=False)

# %%
vectordb=Chroma.from_documents(document_chunks,embedding=embeddings, persist_directory='./data')

# %%
vectordb.persist()

# %%
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-chat-hf",
                                          use_auth_token=True,)


model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-7b-chat-hf",
                                             device_map='auto',
                                             torch_dtype=torch.float16,
                                             use_auth_token=True,
                                              #load_in_8bit=True,
                                              load_in_4bit=True
                                             )
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:640: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading (…)okenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py:479: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading (…)lve/main/config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# Downloading (…)fetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:374: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading (…)neration_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
pipe=pipeline("text-generation",
              model=model,
              tokenizer=tokenizer,
              torch_dtype=torch.bfloat16,
              device_map='auto',
              max_new_tokens=512,
              min_new_tokens=-1,
              top_k=30

              )

# %%
llm=HuggingFacePipeline(pipeline=pipe, model_kwargs={'temperature':0})

# %%
llm
# Out:
# HuggingFacePipeline(cache=None, verbose=False, callbacks=None, callback_manager=None, tags=None, metadata=None, pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x780a9257cf40>, model_id='gpt2', model_kwargs={'temperature': 0}, pipeline_kwargs=None, batch_size=4)

# %%
memory=ConversationBufferMemory(memory_key='chat_history', return_messages=True)

# %%
pdf_qa=ConversationalRetrievalChain.from_llm(llm=llm,
                                             retriever=vectordb.as_retriever(search_kwargs={'k':6}),
                                             verbose=False, memory=memory)

# %%
result=pdf_qa({"question":"What is LLM"})
# Out:
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/nn/modules.py:224: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_type=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(f'Input type into Linear4bit is torch.float16, but bnb_4bit_compute_type=torch.float32 (default). This will lead to slow inference or training speed.')

# %%
result['answer']
# Out:
# ' An LLM is a type of machine learning that can perform natural language processing tasks, including generating and classifying text, answering questions in a conversational manner, and translating text from one language to another.\n\n\n\n'

# %%
# %%writefile app2.py
def main():
  st.title("question and answer app")

  question=st.text_input("what is your question?")

  if st.button("Get answer"):
    with st.spinner("Generation Answer..."):
      response=pdf_qa(question)
    st.success(response)

if __name__=='__main__':
  main()
# Out:
# Writing app2.py

# %%
print('---------------------------------------------------------------------------------')
print('Welcome to the DocBot. You are now ready to start interacting with your documents')
print('---------------------------------------------------------------------------------')

while True:
  query=input(f"Prompt:")
  if query == "exit" or query == "quit" or query == "q" or query == "f":
    print('Exiting')
    sys.exit()
  if query == '':
    continue
  result = pdf_qa({"question": query})
  print(f"Answer: " + result["answer"])
# Out:
# ---------------------------------------------------------------------------------
# Welcome to the DocBot. You are now ready to start interacting with your documents
# ---------------------------------------------------------------------------------
# Prompt:Different types of LLMs
# Answer:   Autoregressive LLMs generate text by predicting the next word in a sequence given the previous words. Canonical LLMs use an RNN to learn sequences of words and hence can predict the next word. Denoising LLMs use a combination of autoregressive and canonical models to generate text.
# Please let me know if you have any further questions.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-e3c6f5c27fee> in <cell line: 5>()
#       4
#       5 while True:
# ----> 6   query=input(f"Prompt:")
#       7   if query == "exit" or query == "quit" or query == "q" or query == "f":
#       8     print('Exiting')
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
stabilityai/StableBeluga-7B
NousResearch/Llama-2-13b-hf
